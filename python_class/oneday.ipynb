# %%
# how to find the type of variable
a=10
print(type(a))

# how to find memory address
num1 = 10.11
num2 = 10.11
print(id(num1))
print(id(num2))

# how to find the size of the memory

import sys

b=10
print(sys.getsizeof(b))
print(sys.version)
#28 bytes
# Out:
# <class 'int'>
# 2771904869328
# 2771935852848
# 28
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(b/a)
print(b//a)
print(b%a)
print(2**3)
# Out:
# 30
# -10
# 200
# 2.0
# 2
# 0
# 8

# %%
side = int(input("Enter a side: "))
print(side*side)
# Out:
# Enter a side:  5
# 25
