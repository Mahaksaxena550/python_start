# %%
print("hello")
# Out:
# hello

# %%
print("hello",end=" ")
print('welcome',end=" ")
print("""students""",end=" ")
rollno=10
print(rollno)
# Out:
# hello welcome students 10

# %%
name = """ Python is a high-level, interpreted, general-purpose programming language,
created by Guido van Rossum and first released in 1991. It is known for its emphasis on code readability, 
achieved through its clear and concise syntax, which often resembles natural language."""

print(name)
# Out:
#  Python is a high-level, interpreted, general-purpose programming language,
# created by Guido van Rossum and first released in 1991. It is known for its emphasis on code readability,
# achieved through its clear and concise syntax, which often resembles natural language.

# %%
a= int(input("enter a number"))
b= int (input("enter a number"))
print(a+b)
