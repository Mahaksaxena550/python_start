# %%
#comparision/relational oprators
a=10
b=20
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
# logical oprators
#print(0 and 1)
#print(1 and 1)
#print(0 or 1)
#print(0 or 0)
print( not 1)
# Out:
# False

# %%
a=int(input ("enter a number: "))
b=int(input ("enter a number: "))
print(a>b)
# Out:
# enter a number:  20
# enter a number:  10
# True

# %%
# comprision + logical oprators
a=2000
b=400
c=60
print(a>b and a>c)
print(b>a and b>c)
print(c>a and c>b)
# Out:
# True
# False
# False

# %%
# bitwise oprators

print(5 & 7)
print (13 & 19)

print ( 13 | 19)

print(13^19)
print(14 ^ 16)
# Out:
# 5
# 1
# 31
# 30
# 30

# %%
x=10
y=20
print(x+y)
print (type(x+y))
print (type(x-y))
print (type(x*y))
print (type(x/y))
# Out:
# 30
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
x=10
y=20
print(x%y)

print(x//y)
# Out:
# 10
# 0

# %%
x=10
y=20

print (x==y)
print (x!=y)
print (x>=y)
print (x>=y)
print (x<y)
print (x<=y)
# Out:
# False
# True
# False
# False
# True
# True
