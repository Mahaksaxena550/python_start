# %%
# area of circle

radius=int(input("Enter a radius "))
print(3.14*radius*radius)
# Out:
# Enter a radius  2
# 12.56

# %%
# area of triangle
height=int(input("Enter a height "))
base=int(input("Enter a base "))
print(1/2*base*height)
# Out:
# Enter a height  5
# Enter a base  2
# 5.0

# %%
# celeius to ferenhite
cileius=int(input("Enter a temperature"))
print((9/5*cileius)+32)
# Out:
# Enter a temperature 15
# 59.0

# %%
#area of cube
a = int(input("Enter a surface area "))
print(6*a*a)
# Out:
# Enter a surface area  4
# 96

# %%
#area of cylinder
radius =  int(input("Enter a radius "))
height =  int(input("Enter a height "))
print(2*3.14*radius*height + 2*3.14*radius*radius)
# Out:
# Enter a radius  5
# Enter a height  6
# 345.4

# %%
# assiangment oprator
a=4
b=2
#a=a+b
#a+=b

#a-=b
#a*=b
#a/=b
#a//=b
#a%=b
#a**=b
print(a)
# Out:
# 2
